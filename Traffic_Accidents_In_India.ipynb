# %%
# Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#Load Dataset

# %%
data = pd.read_csv("driverresponse.csv")

# %%
data.head()
# Out:
#    index  sno            stateut     region  regionid  alcintake2014  \
# 0      0    1     Andhra Pradesh      south         2            594
# 1      1    2  Arunachal Pradesh  northeast         5             11
# 2      2    3              Assam  northeast         5            613
# 3      3    4              Bihar      north         1           1680
# 4      4    5       Chhattisgarh     centre         9            335
#
#    overspeed2014  overtaking2014  lanejumping2014  wrongside2014  ...  \
# 0        12747.0             507              328            668  ...
# 1           16.0               0                0              0  ...
# 2         4596.0             129              104            156  ...
# 3         1496.0             278              236            308  ...
# 4         6720.0             188              313            266  ...
#
#    asleep2014  othercause2014  alcintake2016  overspeed2016  signalavoid2016  \
# ...

# %%
data.tail()
# Out:
#     index  sno       stateut     region  regionid  alcintake2014  \
# 31     31   32  D & N Haveli       west         4              1
# 32     32   33   Daman & Diu       west         4              0
# 33     33   34         Delhi      north         1             51
# 34     34   35   Lakshadweep  southwest         8              0
# 35     35   36    Puducherry      south         2             73
#
#     overspeed2014  overtaking2014  lanejumping2014  wrongside2014  ...  \
# 31           21.0               0                0              0  ...
# 32           21.0               2                2              1  ...
# 33            NaN               0                0              0  ...
# 34            1.0               0                0              0  ...
# 35          250.0             136                0              8  ...
#
#     asleep2014  othercause2014  alcintake2016  overspeed2016  signalavoid2016  \
# ...

# %%
# Data Preprocessing

# %%
print("Missing Values:")
# Out:
# Missing Values:

# %%
print(data.isnull().sum())
# Out:
# index              0
# sno                0
# stateut            0
# region             0
# regionid           0
# alcintake2014      0
# overspeed2014      1
# overtaking2014     0
# lanejumping2014    0
# wrongside2014      0
# signalavoid2014    0
# asleep2014         0
# othercause2014     0
# alcintake2016      0
# overspeed2016      0
# signalavoid2016    0
# wrongside2016      0
# lanejumping2016    0
# overtaking2016     0
# asleep2016         0
# othercause2016     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            36 non-null     int64
#  1   sno              36 non-null     int64
#  2   stateut          36 non-null     object
#  3   region           36 non-null     object
#  4   regionid         36 non-null     int64
#  5   alcintake2014    36 non-null     int64
#  6   overspeed2014    35 non-null     float64
#  7   overtaking2014   36 non-null     int64
#  8   lanejumping2014  36 non-null     int64
#  9   wrongside2014    36 non-null     int64
#  10  signalavoid2014  36 non-null     int64
#  11  asleep2014       36 non-null     int64
#  12  othercause2014   36 non-null     int64
#  13  alcintake2016    36 non-null     int64
#  14  overspeed2016    36 non-null     int64
#  15  signalavoid2016  36 non-null     int64
#  16  wrongside2016    36 non-null     int64
# ...

# %%
print("Number of columns: ",len(data.columns))
print("Number of rows: ",len(data))
# Out:
# Number of columns:  21
# Number of rows:  36

# %%
len(data.select_dtypes(['int64', 'float64']).columns)
# Out:
# 19

# %%
data.isnull().sum()
# Out:
# index              0
# sno                0
# stateut            0
# region             0
# regionid           0
# alcintake2014      0
# overspeed2014      1
# overtaking2014     0
# lanejumping2014    0
# wrongside2014      0
# signalavoid2014    0
# asleep2014         0
# othercause2014     0
# alcintake2016      0
# overspeed2016      0
# signalavoid2016    0
# wrongside2016      0
# lanejumping2016    0
# overtaking2016     0
# asleep2016         0
# othercause2016     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            36 non-null     int64
#  1   sno              36 non-null     int64
#  2   stateut          36 non-null     object
#  3   region           36 non-null     object
#  4   regionid         36 non-null     int64
#  5   alcintake2014    36 non-null     int64
#  6   overspeed2014    35 non-null     float64
#  7   overtaking2014   36 non-null     int64
#  8   lanejumping2014  36 non-null     int64
#  9   wrongside2014    36 non-null     int64
#  10  signalavoid2014  36 non-null     int64
#  11  asleep2014       36 non-null     int64
#  12  othercause2014   36 non-null     int64
#  13  alcintake2016    36 non-null     int64
#  14  overspeed2016    36 non-null     int64
#  15  signalavoid2016  36 non-null     int64
#  16  wrongside2016    36 non-null     int64
# ...

# %%
print("Number of columns: ",len(data.columns))
print("Number of rows: ",len(data))
# Out:
# Number of columns:  21
# Number of rows:  36

# %%
len(data.select_dtypes(['int64', 'float64']).columns)
# Out:
# 19

# %%
data.isnull().sum()
# Out:
# index              0
# sno                0
# stateut            0
# region             0
# regionid           0
# alcintake2014      0
# overspeed2014      1
# overtaking2014     0
# lanejumping2014    0
# wrongside2014      0
# signalavoid2014    0
# asleep2014         0
# othercause2014     0
# alcintake2016      0
# overspeed2016      0
# signalavoid2016    0
# wrongside2016      0
# lanejumping2016    0
# overtaking2016     0
# asleep2016         0
# othercause2016     0
# dtype: int64

# %%
data.isna().sum().sort_values(ascending=False) * 100. / len(data)
# Out:
# overspeed2014      2.777778
# sno                0.000000
# stateut            0.000000
# region             0.000000
# index              0.000000
# regionid           0.000000
# alcintake2014      0.000000
# overtaking2014     0.000000
# lanejumping2014    0.000000
# wrongside2014      0.000000
# signalavoid2014    0.000000
# asleep2014         0.000000
# othercause2014     0.000000
# alcintake2016      0.000000
# overspeed2016      0.000000
# signalavoid2016    0.000000
# wrongside2016      0.000000
# lanejumping2016    0.000000
# overtaking2016     0.000000
# asleep2016         0.000000
# othercause2016     0.000000
# dtype: float64

# %%
missing_data = data.isna().sum().sort_values(ascending=False) * 100. / len(data)

# %%
type(missing_data) #we can directly plot the Pandas.Series using plot()
# Out:
# pandas.core.series.Series

# %%
missing_data.plot(kind='bar')
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['index', 'sno', 'stateut', 'region', 'regionid', 'alcintake2014',
#        'overspeed2014', 'overtaking2014', 'lanejumping2014', 'wrongside2014',
#        'signalavoid2014', 'asleep2014', 'othercause2014', 'alcintake2016',
#        'overspeed2016', 'signalavoid2016', 'wrongside2016', 'lanejumping2016',
#        'overtaking2016', 'asleep2016', 'othercause2016'],
#       dtype='object')

# %%
data.region.unique()
# Out:
# array(['south', 'northeast', 'north', 'centre', 'west', 'east',
#        'northwest', 'southeast', 'southwest'], dtype=object)

# %%
 stateut= data.stateut.unique()
len(stateut)
# Out:
# 36

# %%
stateut_by_accident = data.stateut.value_counts()
stateut_by_accident[:20]
# Out:
# stateut
# Andhra Pradesh       1
# Arunachal Pradesh    1
# Assam                1
# Bihar                1
# Chhattisgarh         1
# Goa                  1
# Gujarat              1
# Haryana              1
# Himachal Pradesh     1
# Jammu & Kashmir      1
# Jharkhand            1
# Karnataka            1
# Kerala               1
# Madhya Pradesh       1
# Maharashtra          1
# Manipur              1
# Meghalaya            1
# Mizoram              1
# Nagaland             1
# Orissa               1
# Name: count, dtype: int64

# %%
'accident' in stateut
# Out:
# False

# %%
high_accident_cstateut = stateut_by_accident[stateut_by_accident >=1000]
low_accident_stateut = stateut_by_accident[stateut_by_accident < 1000]

# %%
# Exploatory data Analysis(EDA)

# %%
data.describe()
# Out:
#            index        sno   regionid  alcintake2014  overspeed2014  \
# count  36.000000  36.000000  36.000000      36.000000      35.000000
# mean   17.500000  18.500000   4.000000     525.444444    5950.600000
# std    10.535654  10.535654   2.746426     767.133866    8677.731983
# min     0.000000   1.000000   1.000000       0.000000       0.000000
# 25%     8.750000   9.750000   1.750000      11.750000      72.500000
# 50%    17.500000  18.500000   4.000000      82.500000    2561.000000
# 75%    26.250000  27.250000   5.000000     706.500000    6493.000000
# max    35.000000  36.000000   9.000000    3540.000000   29790.000000
#
#        overtaking2014  lanejumping2014  wrongside2014  signalavoid2014  \
# count       36.000000        36.000000      36.000000        36.000000
# mean       312.833333       283.361111     302.000000        37.000000
# std        514.513279       462.370115     389.184642        81.196411
# ...

# %%
(data.isnull().sum())
# Out:
# index              0
# sno                0
# stateut            0
# region             0
# regionid           0
# alcintake2014      0
# overspeed2014      1
# overtaking2014     0
# lanejumping2014    0
# wrongside2014      0
# signalavoid2014    0
# asleep2014         0
# othercause2014     0
# alcintake2016      0
# overspeed2016      0
# signalavoid2016    0
# wrongside2016      0
# lanejumping2016    0
# overtaking2016     0
# asleep2016         0
# othercause2016     0
# dtype: int64

# %%
(data.isna())
# Out:
#     index    sno  stateut  region  regionid  alcintake2014  overspeed2014  \
# 0   False  False    False   False     False          False          False
# 1   False  False    False   False     False          False          False
# 2   False  False    False   False     False          False          False
# 3   False  False    False   False     False          False          False
# 4   False  False    False   False     False          False          False
# 5   False  False    False   False     False          False          False
# 6   False  False    False   False     False          False          False
# 7   False  False    False   False     False          False          False
# 8   False  False    False   False     False          False          False
# 9   False  False    False   False     False          False          False
# 10  False  False    False   False     False          False          False
# 11  False  False    False   False     False          False          False
# ...

# %%
# Data Exploration Visualizations

# %%
#Box plot

# %%
stateut_by_accident[:20].plot(kind='barh')
# Out:
# <Axes: ylabel='stateut'>

# %%
sns.histplot(low_accident_stateut, log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
type(missing_data) #we can directly plot the Pandas.Series using plot()
# Out:
# pandas.core.series.Series

# %%
missing_data.plot(kind='bar')
# Out:
# <Axes: >

# %%
missing_data[missing_data > 0].plot(kind='barh')
# Out:
# <Axes: >

# %%
#Histogram plot

# %%
plt.hist(data['overspeed2014'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Speed')
plt.xlabel('Speed')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(data['lanejumping2014'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Speed')
plt.xlabel('Speed')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(data['lanejumping2014'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Speed')
plt.xlabel('Speed')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(data['wrongside2014'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Speed')
plt.xlabel('Speed')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(data['alcintake2014'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Speed')
plt.xlabel('Speed')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(data['asleep2016'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Speed')
plt.xlabel('Speed')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter Plot

# %%
plt.scatter(data['asleep2016'], data['stateut'], alpha=0.6, color='purple')
plt.title('Scatter Plot of Speed vs Reaction Time')
plt.xlabel('Speed')
plt.ylabel('Reaction Time')
plt.show()

# %%
plt.scatter(data['alcintake2014'], data['stateut'], alpha=0.6, color='purple')
plt.title('Scatter Plot of Speed vs Reaction Time')
plt.xlabel('Speed')
plt.ylabel('Reaction Time')
plt.show()

# %%
plt.scatter(data['overspeed2014'], data['stateut'], alpha=0.6, color='purple')
plt.title('Scatter Plot of Speed vs Reaction Time')
plt.xlabel('Speed')
plt.ylabel('Reaction Time')
plt.show()

# %%
# Pie Chart

# %%
driver_counts = data['stateut'].value_counts()
labels = driver_counts.index
sizes = driver_counts.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['gold', 'lightblue', 'pink'], startangle=140)
plt.title('Distribution of Driver Types')
plt.show()

# %%
#pairplot

# %%
sns.pairplot(data)
plt.show()

# %%
print(data.dtypes)
# Out:
# index                int64
# sno                  int64
# stateut             object
# region              object
# regionid             int64
# alcintake2014        int64
# overspeed2014      float64
# overtaking2014       int64
# lanejumping2014      int64
# wrongside2014        int64
# signalavoid2014      int64
# asleep2014           int64
# othercause2014       int64
# alcintake2016        int64
# overspeed2016        int64
# signalavoid2016      int64
# wrongside2016        int64
# lanejumping2016      int64
# overtaking2016       int64
# asleep2016           int64
# othercause2016       int64
# dtype: object

# %%
#duplicate
print(data.duplicated().sum())
# Out:
# 0

# %%
#remove dupli rows
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#     index  sno            stateut     region  regionid  alcintake2014  \
# 0       0    1     Andhra Pradesh      south         2            594
# 1       1    2  Arunachal Pradesh  northeast         5             11
# 2       2    3              Assam  northeast         5            613
# 3       3    4              Bihar      north         1           1680
# 4       4    5       Chhattisgarh     centre         9            335
# 5       5    6                Goa       west         4              9
# 6       6    7            Gujarat       west         4             42
# 7       7    8            Haryana      north         1           1095
# 8       8    9   Himachal Pradesh      north         1             74
# 9       9   10    Jammu & Kashmir      north         1            388
# 10     10   11          Jharkhand     centre         9            611
# 11     11   12          Karnataka      south         2           2207
# ...

# %%
print(data.columns)
# Out:
# Index(['index', 'sno', 'stateut', 'region', 'regionid', 'alcintake2014',
#        'overspeed2014', 'overtaking2014', 'lanejumping2014', 'wrongside2014',
#        'signalavoid2014', 'asleep2014', 'othercause2014', 'alcintake2016',
#        'overspeed2016', 'signalavoid2016', 'wrongside2016', 'lanejumping2016',
#        'overtaking2016', 'asleep2016', 'othercause2016'],
#       dtype='object')

# %%
list(zip(list(data.stateut), list(data.stateut)))
# Out:
# [('Andhra Pradesh', 'Andhra Pradesh'),
#  ('Arunachal Pradesh', 'Arunachal Pradesh'),
#  ('Assam', 'Assam'),
#  ('Bihar', 'Bihar'),
#  ('Chhattisgarh', 'Chhattisgarh'),
#  ('Goa', 'Goa'),
#  ('Gujarat', 'Gujarat'),
#  ('Haryana', 'Haryana'),
#  ('Himachal Pradesh', 'Himachal Pradesh'),
#  ('Jammu & Kashmir', 'Jammu & Kashmir'),
#  ('Jharkhand', 'Jharkhand'),
#  ('Karnataka', 'Karnataka'),
#  ('Kerala', 'Kerala'),
#  ('Madhya Pradesh', 'Madhya Pradesh'),
#  ('Maharashtra', 'Maharashtra'),
#  ('Manipur', 'Manipur'),
#  ('Meghalaya', 'Meghalaya'),
#  ('Mizoram', 'Mizoram'),
#  ('Nagaland', 'Nagaland'),
#  ('Orissa', 'Orissa'),
#  ('Punjab', 'Punjab'),
#  ('Rajasthan', 'Rajasthan'),
#  ('Sikkim', 'Sikkim'),
#  ('Tamil Nadu', 'Tamil Nadu'),
#  ('Telangana', 'Telangana'),
#  ('Tripura', 'Tripura'),
#  ('Uttarakhand', 'Uttarakhand'),
#  ('Uttar Pradesh', 'Uttar Pradesh'),
#  ('West Bengal', 'West Bengal'),
#  ('A & N Islands', 'A & N Islands'),
#  ('Chandigarh', 'Chandigarh'),
# ...

# %%
# Identify Outliers

# %%
z_scores = [-0.71, -0.47, 0.00, 2.94]

# %%
# Outlier Detection Libraries
from scipy.stats import zscore

# %%
z_scores = np.abs(zscore(data.select_dtypes(include=np.number)))

# %%
outliers = np.where(z_scores > 3)  # Threshold set to 3

# %%
print("Number of Outliers:", len(outliers[0]))
# Out:
# Number of Outliers: 14

# %%
# Visualize Outliers

# %%
for column in data.select_dtypes(include=np.number).columns:
    sns.boxplot(data[column])
    plt.title(f"Boxplot of {column}")
    plt.show()

# %%
# Clustering with Original Data

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data.select_dtypes(include=np.number))

# %%
data['stateut']
# Out:
# 0        Andhra Pradesh
# 1     Arunachal Pradesh
# 2                 Assam
# 3                 Bihar
# 4          Chhattisgarh
# 5                   Goa
# 6               Gujarat
# 7               Haryana
# 8      Himachal Pradesh
# 9       Jammu & Kashmir
# 10            Jharkhand
# 11            Karnataka
# 12               Kerala
# 13       Madhya Pradesh
# 14          Maharashtra
# 15              Manipur
# 16            Meghalaya
# 17              Mizoram
# 18             Nagaland
# 19               Orissa
# 20               Punjab
# 21            Rajasthan
# 22               Sikkim
# 23           Tamil Nadu
# 24            Telangana
# 25              Tripura
# 26          Uttarakhand
# 27        Uttar Pradesh
# 28          West Bengal
# 29        A & N Islands
# 30           Chandigarh
# 31         D & N Haveli
# 32          Daman & Diu
# 33                Delhi
# 34          Lakshadweep
# 35           Puducherry
# Name: stateut, dtype: object

# %%
data['stateut'].value_counts()
# Out:
# stateut
# Andhra Pradesh       1
# Arunachal Pradesh    1
# Assam                1
# Bihar                1
# Chhattisgarh         1
# Goa                  1
# Gujarat              1
# Haryana              1
# Himachal Pradesh     1
# Jammu & Kashmir      1
# Jharkhand            1
# Karnataka            1
# Kerala               1
# Madhya Pradesh       1
# Maharashtra          1
# Manipur              1
# Meghalaya            1
# Mizoram              1
# Nagaland             1
# Orissa               1
# Punjab               1
# Rajasthan            1
# Sikkim               1
# Tamil Nadu           1
# Telangana            1
# Tripura              1
# Uttarakhand          1
# Uttar Pradesh        1
# West Bengal          1
# A & N Islands        1
# Chandigarh           1
# D & N Haveli         1
# Daman & Diu          1
# Delhi                1
# Lakshadweep          1
# Puducherry           1
# Name: count, dtype: int64

# %%
print(data.columns)
# Out:
# Index(['index', 'sno', 'stateut', 'region', 'regionid', 'alcintake2014',
#        'overspeed2014', 'overtaking2014', 'lanejumping2014', 'wrongside2014',
#        'signalavoid2014', 'asleep2014', 'othercause2014', 'alcintake2016',
#        'overspeed2016', 'signalavoid2016', 'wrongside2016', 'lanejumping2016',
#        'overtaking2016', 'asleep2016', 'othercause2016'],
#       dtype='object')

# %%
stateut = data.stateut.value_counts()

# %%
stateut[stateut > 1000]
# Out:
# Series([], Name: count, dtype: int64)

# %%
regionid = data.regionid.value_counts()

# %%
regionid[regionid > 1000]
# Out:
# Series([], Name: count, dtype: int64)

# %%
import matplotlib.pyplot as plt

# %%
driver_counts = data['regionid'].value_counts()
labels = driver_counts.index
sizes = driver_counts.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['gold', 'lightblue', 'pink'], startangle=140)
plt.title('Distribution of Driver Types')
plt.show()

# %%
data[ 'regionid']
# Out:
# 0     2
# 1     5
# 2     5
# 3     1
# 4     9
# 5     4
# 6     4
# 7     1
# 8     1
# 9     1
# 10    9
# 11    2
# 12    2
# 13    9
# 14    4
# 15    5
# 16    5
# 17    3
# 18    5
# 19    9
# 20    1
# 21    6
# 22    5
# 23    2
# 24    9
# 25    3
# 26    1
# 27    1
# 28    3
# 29    7
# 30    1
# 31    4
# 32    4
# 33    1
# 34    8
# 35    2
# Name: regionid, dtype: int64

# %%
data['regionid'].value_counts()
# Out:
# regionid
# 1    9
# 5    6
# 2    5
# 9    5
# 4    5
# 3    3
# 6    1
# 7    1
# 8    1
# Name: count, dtype: int64

# %%
data['overspeed2014']
# Out:
# 0     12747.0
# 1        16.0
# 2      4596.0
# 3      1496.0
# 4      6720.0
# 5      3148.0
# 6     13752.0
# 7      4185.0
# 8      2763.0
# 9      2859.0
# 10     1627.0
# 11    23370.0
# 12    20611.0
# 13    20967.0
# 14    29790.0
# 15        0.0
# 16       40.0
# 17       48.0
# 18       51.0
# 19     3699.0
# 20     2253.0
# 21    11395.0
# 22       28.0
# 23    28804.0
# 24     6266.0
# 25      499.0
# 26       94.0
# 27     2561.0
# 28     3339.0
# 29       94.0
# 30      160.0
# 31       21.0
# 32       21.0
# 33        NaN
# 34        1.0
# 35      250.0
# Name: overspeed2014, dtype: float64

# %%
regionid.index
# Out:
# Index([1, 5, 2, 9, 4, 3, 6, 7, 8], dtype='int64', name='regionid')

# %%
regionid.values
# Out:
# array([9, 6, 5, 5, 5, 3, 1, 1, 1])

# %%
# Load your data into final_data
final_data = pd.read_csv("driverresponse.csv")

# %%
final_data.isnull().sum()
# Out:
# index              0
# sno                0
# stateut            0
# region             0
# regionid           0
# alcintake2014      0
# overspeed2014      1
# overtaking2014     0
# lanejumping2014    0
# wrongside2014      0
# signalavoid2014    0
# asleep2014         0
# othercause2014     0
# alcintake2016      0
# overspeed2016      0
# signalavoid2016    0
# wrongside2016      0
# lanejumping2016    0
# overtaking2016     0
# asleep2016         0
# othercause2016     0
# dtype: int64

# %%
print(final_data.columns)
# Out:
# Index(['index', 'sno', 'stateut', 'region', 'regionid', 'alcintake2014',
#        'overspeed2014', 'overtaking2014', 'lanejumping2014', 'wrongside2014',
#        'signalavoid2014', 'asleep2014', 'othercause2014', 'alcintake2016',
#        'overspeed2016', 'signalavoid2016', 'wrongside2016', 'lanejumping2016',
#        'overtaking2016', 'asleep2016', 'othercause2016'],
#       dtype='object')

# %%
final_data.columns = final_data.columns.str.strip()

# %%
print("Stateut Code: ", final_data['stateut'].unique())  # If it's lowercase 'stateut'
print("Total No. of Stateut in Dataset: ", len(final_data['stateut'].unique()))
# Out:
# Stateut Code:  ['Andhra Pradesh' 'Arunachal Pradesh' 'Assam' 'Bihar' 'Chhattisgarh' 'Goa'
#  'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jammu & Kashmir' 'Jharkhand'
#  'Karnataka' 'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Manipur' 'Meghalaya'
#  'Mizoram' 'Nagaland' 'Orissa' 'Punjab' 'Rajasthan' 'Sikkim' 'Tamil Nadu'
#  'Telangana' 'Tripura' 'Uttarakhand' 'Uttar Pradesh' 'West Bengal'
#  'A & N Islands' 'Chandigarh' 'D & N Haveli' 'Daman & Diu' 'Delhi'
#  'Lakshadweep' 'Puducherry']
# Total No. of Stateut in Dataset:  36

# %%
if 'stateut' in final_data.columns:
    fig, ax = plt.subplots(figsize=(20, 5))

    c = sns.countplot(
        x='stateut', 
        data=final_data, 
        order=final_data['stateut'].value_counts().index
    )

    c.set_title("State/UT with Number of Accidents")
    c.set_xlabel("State/Union Territory")
    c.set_ylabel("Number of Accidents")
    plt.xticks(rotation=45, ha='right')  
    plt.tight_layout() 
    plt.show()
else:
    print("The 'stateut' column is not present in the dataset.")

# %%
print(final_data.columns)
# Out:
# Index(['index', 'sno', 'stateut', 'region', 'regionid', 'alcintake2014',
#        'overspeed2014', 'overtaking2014', 'lanejumping2014', 'wrongside2014',
#        'signalavoid2014', 'asleep2014', 'othercause2014', 'alcintake2016',
#        'overspeed2016', 'signalavoid2016', 'wrongside2016', 'lanejumping2016',
#        'overtaking2016', 'asleep2016', 'othercause2016'],
#       dtype='object')

# %%
import difflib
print(difflib.get_close_matches("Start_Time", final_data.columns))
# Out:
# []

# %%
final_data = pd.read_csv("driverresponse.csv")
print(final_data.columns)
# Out:
# Index(['index', 'sno', 'stateut', 'region', 'regionid', 'alcintake2014',
#        'overspeed2014', 'overtaking2014', 'lanejumping2014', 'wrongside2014',
#        'signalavoid2014', 'asleep2014', 'othercause2014', 'alcintake2016',
#        'overspeed2016', 'signalavoid2016', 'wrongside2016', 'lanejumping2016',
#        'overtaking2016', 'asleep2016', 'othercause2016'],
#       dtype='object')

# %%
# Correct the column name
final_data.rename(columns={'start_time': 'Start_Time'}, inplace=True)

# %%
final_data.columns = final_data.columns.str.strip()

# %%
# Example of creating a placeholder datetime column
final_data['Start_Time'] = pd.to_datetime("2023-01-01")

# %%
print(final_data['Start_Time'].head())
# Out:
# 0   2023-01-01
# 1   2023-01-01
# 2   2023-01-01
# 3   2023-01-01
# 4   2023-01-01
# Name: Start_Time, dtype: datetime64[ns]

# %%
final_data['Start_Time'] = pd.to_datetime(final_data['Start_Time'], errors='coerce')

# %%
# Extract Year from Start_Time column
final_data['Year'] = final_data['Start_Time'].dt.year

# %%
c.set_title("No. of Accidents per Year", fontsize=14)
c.set_xlabel("Year")
c.set_ylabel("Accident Count")
# Out:
# Text(24.000000000000007, 0.5, 'Accident Count')

# %%
fig, ax = plt.subplots(figsize=(10, 5))

# Create countplot with hue as Year and legend=False
c = sns.countplot(x="Year", data=final_data, palette="crest", hue="Year", legend=False)

plt.annotate('Data Not Available', xy=(-0.4, 500000), fontsize=11)

c.set_title("No. of Accidents in Year")
# Out:
# Text(0.5, 1.0, 'No. of Accidents in Year')
